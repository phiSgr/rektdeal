// %%
%use dataframe
@file:DependsOn("com.github.phisgr:rektdeal:0.3.0")
import com.github.phisgr.dds.*
import com.github.phisgr.rektdeal.*
println("Kotlin Jupyter cache warm-up complete.")
